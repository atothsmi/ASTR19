# %% [markdown]
# # Setting Matplotlib Defaults for ASTR 19
#
# In ASTR 19, we do really love our figures! In this class, we are going to create a Matplotlib style that sets the defaults for our figures. This exercise will help save us some time in the future.

# %%
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# Before getting started, let's look at the default colors

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

print(colors)
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# Make a figure showing the default colors

# %%
fig = plt.figure(figsize=(5,5),linewidth=1)
ax = plt.subplot(1,1,1, aspect =1)

x = np.linspace(0, 10, 100)

for i, color in enumerate(colors):
    y = np.full(100, float(i))
    ax.plot(x, y, color=color, label=color)

ax.set_xlabel('x')
ax.set_ylabel('y')

l = ax.legend()

for i, text in enumerate(l.get_texts()):
    text.set_color(colors[i])

plt.show()

# %% [markdown]
# We already saw before that there also exists many aliases for matplotlib colors

# %%
import matplotlib as mpl

colors = mpl.colors.cnames.keys()
num_colors = len(colors)
print(f'There are {num_colors} different colors.')

fig = plt.figure(figsize=(10,10))

for i, color in enumerate(colors):
    col = np.array(float(i%10))
    row = np.array(int(i//10))
    plt.plot(col, row, marker='s', markersize=15, color=color)
    plt.annotate(color, (col-0.3, row+0.3), fontsize=6) #someString, tuple coordinates

plt.show()
# Out:
# There are 148 different colors.

# %% [markdown]
# Enough with the defaults, let's make our own

# %%
#create some data to plot
x = np.linspace(-np.pi, np.pi, 256, endpoint = True)
c = np.cos(x)
s = np.sin(x)

# %%
#make a plot using matplotlib default
fig =plt.figure(linewidth=1, figsize=(10,5))
ax = plt.subplot(1,1,1, aspect=1)

ax.plot(x, c, label='cos(x)')
ax.plot(x, s, label='sin(x)')

ax.set_yticks([-1, 0, 1])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend()
plt.show()

# %%
# !cat astr19_matplotlib_defaults.txt
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#read in our default
plt.style.use('astr19-matplotlib-defaults.txt')

# %%
fig = plt.figure()
ax = plt.subplot(1,1,1, aspect =1)

ax.plot(x, c, label='cos(x)')
ax.plot(x, s, label='sin(x)')

colors= list(colors)

#markevery nth point, clip_on include last point as marker?
ax.plot(x, c, 'o', markevery=10, clip_on=False, zorder=10, markersize=6, color='#1f77b4') 
ax.plot(x, s, 'o', markevery=10, clip_on=False, zorder=10, markersize=6, color='#ff7f0e') 

ax.plot(x, c, 'o', markevery=10, clip_on=False, zorder=11, markersize=3, color='white') 
ax.plot(x, s, 'o', markevery=10, clip_on=False, zorder=11, markersize=3, color='white') 

ax.set_yticks([-1, 0, 1])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend()
plt.show()

# %%
# print(plt.rcParams)
