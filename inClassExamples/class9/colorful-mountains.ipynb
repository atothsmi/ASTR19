# %% [markdown]
# # Create a colorful, stylized mountain range

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# %%
#create a figure
f = plt.figure(figsize=(5,10))

#get the turbo color map
cmap_turbo = cm.get_cmap('turbo')

#add a single subplot to the figure
#with empty x and y ticklabels
#and no axes shown
ax = f.add_subplot(111, xticks = [], yticks=[])
ax.set_axis_off()

#set the limits to the x and y axes
ax.set_xlim([0, 2*np.pi])
ax.set_ylim([0, 15.])

#create an x array [0, 2pi]
x = np.linspace(0, 2*np.pi, 100)

#set teh number of mountain ranges
num_mr = 10

#set the number of peaks in each range
npeak = 10

for i in range(num_mr):
    #set the color of the moutain range
    #by providing a number [0 , 1]
    mr_color = cmap_turbo(float(i)/float(npeak))

    #create a frequency
    freq = 3*np.random.rand(npeak) + 1

    #create a phase
    phase = 2*np.pi * np.random.rand(npeak)

    #set an amplitude
    amp = np.random.rand(npeak) + 0.01

    #set a y offset so each range is offset along the y direction
    y_offset = 1 * float(i)

    #create the mountain range
    y = np.zeros_like(x)

    #for each peak
    for j in range(npeak):
        #add this peak as a sine curve
        y += amp[j] * np.sin(freq[j]*x + phase[j])

    y = np.abs(y) + y_offset

    plt.fill_between(x, y, y_offset, zorder = num_mr - i, color = mr_color, cmap = 'turbo')





plt.savefig('mountain-range.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\mawhi\AppData\Local\Temp\ipykernel_24432\4047379505.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_turbo = cm.get_cmap('turbo')

# %%
from matplotlib.colors import LinearSegmentedColormap

#define the RGB colorvlaues for the gradient
color1 = (255/255,0,0) #top color (red)
color2 = (255/255, 255/255, 0) #middle color (yellow)
color3 = (0, 255/255, 0) #bottom color (green)

#define the colores and positions for the color map
colors = [color1, color2, color3]
positions = [0, .5, 1]


print(list(zip( positions, colors)))
#create Line
cmap_background = LinearSegmentedColormap.from_list('vertical-gradient', list(zip(positions,colors)))
gradient = np.linspace(0, 1, 100)

#create a figure
f = plt.figure(figsize=(5,10))

#get the turbo color map
cmap_turbo = cm.get_cmap('turbo')

#add a single subplot to the figure
#with empty x and y ticklabels
#and no axes shown
ax = f.add_subplot(111, xticks = [], yticks=[])
ax.set_axis_off()

#set the limits to the x and y axes
ax.set_xlim([0, 2*np.pi])
ax.set_ylim([0, 15.])

#create an x array [0, 2pi]
x = np.linspace(0, 2*np.pi, 100)

#set teh number of mountain ranges
num_mr = 10

#set the number of peaks in each range
npeak = 10

for i in range(num_mr):
    #set the color of the moutain range
    #by providing a number [0 , 1]
    mr_color = cmap_turbo(float(i)/float(npeak))

    #create a frequency
    freq = 3*np.random.rand(npeak) + 1

    #create a phase
    phase = 2*np.pi * np.random.rand(npeak)

    #set an amplitude
    amp = np.random.rand(npeak) + 0.01

    #set a y offset so each range is offset along the y direction
    y_offset = 1 * float(i)

    #create the mountain range
    y = np.zeros_like(x)

    #for each peak
    for j in range(npeak):
        #add this peak as a sine curve
        y += amp[j] * np.sin(freq[j]*x + phase[j])

        y = np.abs(y)

    plt.fill_between(x, y+ y_offset, y_offset, zorder = num_mr - i, color = mr_color, cmap = 'turbo')

x_min, x_max = ax.get_xlim()
y_min, y_max = ax.get_ylim()


ax.imshow(gradient.reshape(-1, 1), zorder= -1, cmap=cmap_background , aspect = 'auto', extent=[x_min, x_max, y_min, y_max])  

# ax.imshow([[0,0],[1,1]], zorder= -1, cmap = cmap_background, aspect = 'auto', extent=[x_min, x_max, y_min, y_max])
# plt.savefig('mountain-range.png', bbox_inches='tight')
plt.show()
# Out:
# [(0, (1.0, 0, 0)), (0.5, (1.0, 1.0, 0)), (1, (0, 1.0, 0))]
# C:\Users\mawhi\AppData\Local\Temp\ipykernel_24432\1262919785.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_turbo = cm.get_cmap('turbo')
