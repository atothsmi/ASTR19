# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

theta = np.linspace(0,2*np.pi,100)
x = np.cos(theta)
y = np.sin(theta)

r = (x**2 + y**2)**0.5

ax = plt.subplot(111, projection='polar')
ax.plot(theta, r)

plt.show()
