# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 100)
y = np.sin(5 * x)

plt.plot(x, y)

plt.xlabel('x')
plt.ylabel('sin(5x)')

plt.savefig('demo.png',facecolor='blue', )
# plt.show()
